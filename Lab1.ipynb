# %% [markdown]
# <a href="https://colab.research.google.com/github/miacastanedago/MetNumUN2022II/blob/main/Lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **My own example 1**

# %%
#1
5+1
# Out:
# 6

# %%
#2
54+21
# Out:
# 75

# %%
#3
95+21
# Out:
# 116

# %%
#4
4+2
# Out:
# 6

# %%
#5
88+23
# Out:
# 111

# %%
#6
64+5
# Out:
# 69

# %%
#7
75+4
# Out:
# 79

# %%
#8
54+21
# Out:
# 75

# %%
#9
75+1
# Out:
# 76

# %%
#10
7+84
# Out:
# 91

# %%
#11
7+4+8
# Out:
# 19

# %% [markdown]
# ## **My own example 2**

# %%
#1
j = 215

# %%
#2
a = 5

# %%
#3
b = 8

# %%
#4
c = 10

# %%
#5
d = 85

# %%
#6
e = 86

# %%
#7
f = 91

# %%
#8
g = 5

# %%
#9
h = 546

# %%
#10
i = 845

# %%
#11
k = 258

# %% [markdown]
# ## **My own example 3**

# %%
#1
print(4 + 25)
83 + 35
# Out:
# 29
# 118

# %%
#2
print(94 +6)
5 + 6
# Out:
# 100
# 11

# %%
#3
print(45 + 5)
8 + 2
# Out:
# 50
# 10

# %%
#4
print(4 + 25)
83 + 35
# Out:
# 29
# 118

# %%
#5
print(54 + 5)
83 + 86
# Out:
# 59
# 169

# %%
#6
print(5 +855)
14 + 2
# Out:
# 860
# 16

# %%
#7
print(54 + 8)
15 + 2
# Out:
# 62
# 17

# %%
#8
print(85 + 50)
615 + 40
# Out:
# 135
# 655

# %%
#9
print(5 + 85)
30 + 64
# Out:
# 90
# 94

# %%
#10
print(50 + 25)
36 + 85
# Out:
# 75
# 121

# %%
#10
print(65 + 85)
85 + 21
# Out:
# 150
# 106

# %% [markdown]
# ## **My own example 4**

# %%
#Take some time to run something
c = 0
for i in range(10000000):
    c = c + i
c
# Out:
# 49999995000000

# %%
#Take some time to run something
a = 0
for i in range(20000000):
    a = a + i
a
# Out:
# 199999990000000

# %%
#Take some time to run something
b = 0
for i in range(3000000):
    b = b + i
b
# Out:
# 4499998500000

# %%
#Take some time to run something
d = 0
for i in range(7000000):
    d = d + i
d
# Out:
# 24499996500000

# %%
#Take some time to run something
e = 0
for i in range(6000000):
    e = e + i
e
# Out:
# 17999997000000

# %%
#Take some time to run something
f = 0
for i in range(50000000):
    f = f + i
f
# Out:
# 1249999975000000

# %%
#Take some time to run something
g = 0
for i in range(5000000):
    g = g + i
g
# Out:
# 12499997500000

# %%
#Take some time to run something
h = 0
for i in range(400000):
    h = h + i
h
# Out:
# 79999800000

# %%
#Take some time to run something
i = 0
for i in range(3000000):
    i = i + i
i
# Out:
# 5999998

# %%
#Take some time to run something
j = 0
for i in range(45000000):
    j = j + i
j
# Out:
# 1012499977500000

# %%
#Take some time to run something
k = 0
for i in range(4000000):
    k = k + i
k
# Out:
# 7999998000000

# %% [markdown]
# ## **My own example 5**

# %%
np.random.normal?

# %%
abs?

# %%
np.bool_?

# %%
class?
# Out:
# Object `class` not found.

# %%
delattr?

# %%
else?
# Out:
# Object `else` not found.

# %%
elif?
# Out:
# Object `elif` not found.

# %%
exit?

# %%
if?
# Out:
# Object `if` not found.

# %%
bool?

# %%
and?
# Out:
# Object `and` not found.

# %% [markdown]
# ## **My own example 6**

# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import SciPy as sc

# %%
import Bokeh as bk

# %%
import Seaborn as ab

# %%
import Numba as nm

# %%
import Scikit-Learn as sl

# %%
import TensorFlow as tf

# %%
import Keras as kr

# %%
import yfinance as yf

# %% [markdown]
# ## **My own example 7**

# %%
a = np.random.normal(0, 1, 100)
a
# Out:
# array([ 0.41949552,  0.34216399, -0.6115003 ,  0.50665921, -0.03888981,
#         0.6954163 ,  0.61791756,  0.07155082,  0.36692025,  1.11348732,
#         0.07278088, -0.08444371,  2.13594455, -0.97530244, -0.47928268,
#         0.22987537,  2.21513901,  0.41539662,  1.63110727, -0.4709952 ,
#        -0.06364613,  0.56015018, -0.7777168 ,  2.59196999,  0.60065857,
#        -0.40322415,  0.41348995, -0.27199422, -1.79320079,  0.55979025,
#        -0.33303596,  1.11401407, -0.05295591, -0.05125058, -0.73231498,
#         0.17106128,  0.35438423,  0.53175789, -0.20670459, -1.09825805,
#         0.26586261, -1.3779599 ,  0.78696716,  0.87830324,  0.43035481,
#         0.37255727,  1.45822834,  1.18917708,  0.70593452,  0.67700734,
#        -0.47391916, -0.9559656 , -0.83392669,  0.23151377,  0.36994402,
#         0.02191777, -0.58170228,  0.7109013 , -0.35843258, -1.80062155,
#        -0.6906582 , -1.84108415, -0.1158628 ,  1.08806619,  0.81789002,
#         0.27916056, -1.37679703,  0.91583741, -0.28013284, -0.54302787,
#        -1.73299245, -0.73753282, -1.72328267,  3.3050074 ,  0.24414072,
#         0.7935172 ,  0.49335702,  1.91991699,  0.10670421, -0.08683478,
#        -0.43054364, -0.13700659,  0.72887874,  0.98470586,  0.2883619 ,
#         0.02270507,  0.4577073 , -1.36881905,  1.73704146, -1.87075854,
#        -1.72025563, -0.31660872,  0.30110902, -0.7925047 , -0.25537187,
#        -0.08737358, -0.42739609,  0.08182761, -1.3028546 , -0.57016963])

# %%
b = np.random.normal(0, 1, 20)
b
# Out:
# array([-1.07561339,  0.54929232, -1.9999725 ,  0.27360403,  0.57669367,
#         2.03191629,  1.81622616, -0.79393506, -2.91255933,  2.00741885,
#        -0.24444509,  0.43727513, -0.95561129,  1.41096077,  0.28307603,
#        -1.30418844,  0.08025122, -1.08605794, -2.29572594, -0.96136358])

# %%
c = np.random.normal(0, 1, 25)
c
# Out:
# array([ 0.93417035, -0.33287469, -0.33602468, -0.24443042,  1.16010555,
#         2.28005388, -0.40570447, -1.41713736, -0.71377917,  0.97072743,
#         0.56602633, -0.2158355 ,  0.34037721, -0.92132751,  0.48766336,
#        -1.37778658,  0.9161632 ,  0.31429763,  1.05539662, -1.37247403,
#         0.34280062, -0.57259787,  0.66295486,  0.42345446,  0.93442298])

# %%
d = np.random.normal(0, 1, 30)
d
# Out:
#        -0.29922958,  0.47524713, -1.01241261, -1.29611722, -0.1380396 ,
#        -0.90480273,  0.65821556,  0.07635351,  0.86790644,  1.14375733,
#        -0.4914    , -0.75101478,  2.42938936, -0.48647579, -0.05559383,
#         0.28925152, -0.34406376, -0.24824344,  0.21809137,  0.26769239,
#         0.7477973 ,  0.79692376,  1.06089511,  0.79665795,  0.35448401,
#        -0.51891873,  0.49559583, -1.13508772,  0.54336511,  1.33148641,
#         0.01842533, -0.6935116 , -2.58951674, -0.46925646,  0.4462665 ])

# %% [markdown]
# ## **My own example 8**

# %%
plt.plot(a)

# %%
plt.plot(b)

# %%
plt.plot(c)

# %%
plt.plot(d)

# %%
plt.plot(e)

# %%
plt.plot(f)

# %%
plt.plot(g)

# %%
plt.plot(h)

# %%
plt.plot(i)

# %%
plt.plot(j)

# %%
plt.plot(k)

# %% [markdown]
# ## **My own example 9**

# %%
X = np.random.normal(0, 1, 10)
X2 = np.random.normal(0, 1, 10)

plt.plot(X);
plt.plot(X2);

# %%
X = np.random.normal(0, 1, 20)
X2 = np.random.normal(0, 1, 20)

plt.plot(X);
plt.plot(X2);

# %%
X = np.random.normal(0, 1, 25)
X2 = np.random.normal(0, 1, 25)

plt.plot(X);
plt.plot(X2);

# %%
X = np.random.normal(0, 1, 30)
X2 = np.random.normal(0, 1, 30)

plt.plot(X);
plt.plot(X2);

# %%
X = np.random.normal(0, 1, 35)
X2 = np.random.normal(0, 1, 35)

plt.plot(X);
plt.plot(X2);

# %%
X = np.random.normal(0, 1, 40)
X2 = np.random.normal(0, 1, 40)

plt.plot(X);
plt.plot(X2);

# %%
X = np.random.normal(0, 1, 45)
X2 = np.random.normal(0, 1, 45)

plt.plot(X);
plt.plot(X2);

# %%
X = np.random.normal(0, 1, 50)
X2 = np.random.normal(0, 1, 50)

plt.plot(X);
plt.plot(X2);

# %%
X = np.random.normal(0, 1, 55)
X2 = np.random.normal(0, 1, 55)

plt.plot(X);
plt.plot(X2);

# %%
X = np.random.normal(0, 1, 60)
X2 = np.random.normal(0, 1, 60)

plt.plot(X);
plt.plot(X2);

# %%
X = np.random.normal(0, 1, 65)
X2 = np.random.normal(0, 1, 65)

plt.plot(X);
plt.plot(X2);

# %% [markdown]
# ## **My own example 10**

# %%
X = np.random.normal(0, 1, 10)
X2 = np.random.normal(0, 1, 10)

plt.plot(X);
plt.plot(X2);
plt.xlabel('Time') # The data we generated is unitless, but don't forget units in general.
plt.ylabel('Returns')
# Out:
# Text(0, 0.5, 'Returns')

# %%
X = np.random.normal(0, 1, 20)
X2 = np.random.normal(0, 1, 20)

plt.plot(X);
plt.plot(X2);
plt.xlabel('Time') # The data we generated is unitless, but don't forget units in general.
plt.ylabel('Returns')
# Out:
# Text(0, 0.5, 'Returns')

# %%
X = np.random.normal(0, 1, 25)
X2 = np.random.normal(0, 1, 25)

plt.plot(X);
plt.plot(X2);
plt.xlabel('Time') # The data we generated is unitless, but don't forget units in general.
plt.ylabel('Returns')
# Out:
# Text(0, 0.5, 'Returns')

# %%
X = np.random.normal(0, 1, 30)
X2 = np.random.normal(0, 1, 30)

plt.plot(X);
plt.plot(X2);
plt.xlabel('Time') # The data we generated is unitless, but don't forget units in general.
plt.ylabel('Returns')
# Out:
# Text(0, 0.5, 'Returns')

# %%
X = np.random.normal(0, 1, 35)
X2 = np.random.normal(0, 1, 35)

plt.plot(X);
plt.plot(X2);
plt.xlabel('Time') # The data we generated is unitless, but don't forget units in general.
plt.ylabel('Returns')
# Out:
# Text(0, 0.5, 'Returns')

# %%
X = np.random.normal(0, 1, 40)
X2 = np.random.normal(0, 1, 40)

plt.plot(X);
plt.plot(X2);
plt.xlabel('Time') # The data we generated is unitless, but don't forget units in general.
plt.ylabel('Returns')
# Out:
# Text(0, 0.5, 'Returns')

# %%
X = np.random.normal(0, 1, 45)
X2 = np.random.normal(0, 1, 45)

plt.plot(X);
plt.plot(X2);
plt.xlabel('Time') # The data we generated is unitless, but don't forget units in general.
plt.ylabel('Returns')
# Out:
# Text(0, 0.5, 'Returns')

# %%
X = np.random.normal(0, 1, 50)
X2 = np.random.normal(0, 1, 50)

plt.plot(X);
plt.plot(X2);
plt.xlabel('Time') # The data we generated is unitless, but don't forget units in general.
plt.ylabel('Returns')
# Out:
# Text(0, 0.5, 'Returns')

# %%
X = np.random.normal(0, 1, 55)
X2 = np.random.normal(0, 1, 55)

plt.plot(X);
plt.plot(X2);
plt.xlabel('Time') # The data we generated is unitless, but don't forget units in general.
plt.ylabel('Returns')
# Out:
# Text(0, 0.5, 'Returns')

# %%
X = np.random.normal(0, 1, 60)
X2 = np.random.normal(0, 1, 60)

plt.plot(X);
plt.plot(X2);
plt.xlabel('Time') # The data we generated is unitless, but don't forget units in general.
plt.ylabel('Returns')
# Out:
# Text(0, 0.5, 'Returns')

# %%
X = np.random.normal(0, 1, 65)
X2 = np.random.normal(0, 1, 65)

plt.plot(X);
plt.plot(X2);
plt.xlabel('Time') # The data we generated is unitless, but don't forget units in general.
plt.ylabel('Returns')
# Out:
# Text(0, 0.5, 'Returns')

# %% [markdown]
# ## **My own example 11**

# %%
X = np.random.normal(0, 1, 100)
np.mean(X)
# Out:
# 0.05584617114179374

# %%
X = np.random.normal(0, 1, 100)
np.mean(X)
# Out:
# 0.09671343559310382

# %%
X = np.random.normal(0, 1, 100)
np.mean(X)
# Out:
# -0.11830024288456967

# %%
X = np.random.normal(0, 1, 100)
np.mean(X)
# Out:
# -0.01367449598316161

# %%
X = np.random.normal(0, 1, 100)
np.mean(X)
# Out:
# -0.09259526218443152

# %%
X = np.random.normal(0, 1, 100)
np.mean(X)
# Out:
# 0.030415368984748423

# %%
X = np.random.normal(0, 1, 100)
np.mean(X)
# Out:
# -0.0154001628224253

# %%
X = np.random.normal(0, 1, 100)
np.mean(X)
# Out:
# -0.009175769883226294

# %%
X = np.random.normal(0, 1, 100)
np.mean(X)
# Out:
# 0.0548930568176157

# %%
X = np.random.normal(0, 1, 100)
np.mean(X)
# Out:
# -0.030169970825372233

# %%
X = np.random.normal(0, 1, 100)
np.mean(X)
# Out:
# -0.2168601515633063

# %% [markdown]
# ## **My own example 12**

# %%
# !pip install yfinance
import yfinance as yf

data1 = yf.download("MSFT", start="2012-1-1", end="2012-6-1")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: yfinance in /usr/local/lib/python3.7/dist-packages (0.1.74)
# Requirement already satisfied: lxml>=4.5.1 in /usr/local/lib/python3.7/dist-packages (from yfinance) (4.9.1)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.21.6)
# Requirement already satisfied: requests>=2.26 in /usr/local/lib/python3.7/dist-packages (from yfinance) (2.28.1)
# Requirement already satisfied: pandas>=0.24.0 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.3.5)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from yfinance) (0.0.11)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yfinance) (2022.2.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yfinance) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.24.0->yfinance) (1.15.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2.10)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2022.6.15)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (1.24.3)
# [*********************100%***********************]  1 of 1 completed

# %%
# !pip install yfinance
import yfinance as yf

data2 = yf.download("MSFT", start="2012-6-1", end="2013-1-1")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: yfinance in /usr/local/lib/python3.7/dist-packages (0.1.74)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.21.6)
# Requirement already satisfied: lxml>=4.5.1 in /usr/local/lib/python3.7/dist-packages (from yfinance) (4.9.1)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from yfinance) (0.0.11)
# Requirement already satisfied: requests>=2.26 in /usr/local/lib/python3.7/dist-packages (from yfinance) (2.28.1)
# Requirement already satisfied: pandas>=0.24.0 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.3.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yfinance) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yfinance) (2022.2.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.24.0->yfinance) (1.15.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (1.24.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2022.6.15)
# [*********************100%***********************]  1 of 1 completed

# %%
# !pip install yfinance
import yfinance as yf

data3 = yf.download("MSFT", start="2013-1-1", end="2013-6-1")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: yfinance in /usr/local/lib/python3.7/dist-packages (0.1.74)
# Requirement already satisfied: requests>=2.26 in /usr/local/lib/python3.7/dist-packages (from yfinance) (2.28.1)
# Requirement already satisfied: pandas>=0.24.0 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.3.5)
# Requirement already satisfied: lxml>=4.5.1 in /usr/local/lib/python3.7/dist-packages (from yfinance) (4.9.1)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from yfinance) (0.0.11)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.21.6)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yfinance) (2022.2.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yfinance) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.24.0->yfinance) (1.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2022.6.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (1.24.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2.1.0)
# [*********************100%***********************]  1 of 1 completed

# %%
# !pip install yfinance
import yfinance as yf

# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2017-01-03  62.790001  62.840000  62.130001  62.580002  57.807831  20694100
# 2017-01-04  62.480000  62.750000  62.119999  62.299999  57.549171  21340000
# 2017-01-05  62.189999  62.660000  62.029999  62.299999  57.549171  24876000
# 2017-01-06  62.299999  63.150002  62.040001  62.840000  58.047997  19922900
# 2017-01-09  62.759998  63.080002  62.540001  62.639999  57.863258  20382700
# ...               ...        ...        ...        ...        ...       ...
# 2017-05-24  68.870003  68.879997  68.449997  68.769997  64.277245  14593900
# 2017-05-25  68.970001  69.879997  68.910004  69.620003  65.071739  21854100
# 2017-05-26  69.800003  70.220001  69.519997  69.959999  65.389511  19827900
# 2017-05-30  69.790001  70.410004  69.769997  70.410004  65.810112  17072800
# 2017-05-31  70.529999  70.739998  69.809998  69.839996  65.277336  30436400
#
# [103 rows x 6 columns]

# %% [markdown]
# ## **My own example 14**

# %%
np.std(data1)
# Out:
# Open         1.488071e+00
# High         1.445917e+00
# Low          1.473768e+00
# Close        1.436274e+00
# Adj Close    1.197276e+00
# Volume       1.850600e+07
# dtype: float64

# %%
np.std(data2)
# Out:
# Open         1.404513e+00
# High         1.409042e+00
# Low          1.402385e+00
# Close        1.428911e+00
# Adj Close    1.088980e+00
# Volume       1.675761e+07
# dtype: float64

# %%
np.std(data3)
# Out:
# Open         2.524920e+00
# High         2.615370e+00
# Low          2.530615e+00
# Close        2.619094e+00
# Adj Close    2.279434e+00
# Volume       1.953800e+07
# dtype: float64

# %%
np.std(data4)
# Out:
# Open         2.124068e+00
# High         2.119681e+00
# Low          2.110190e+00
# Close        2.126472e+00
# Adj Close    1.889020e+00
# Volume       3.063323e+07
# dtype: float64

# %%
np.std(data5)
# Out:
# Open         1.645925e+00
# High         1.659529e+00
# Low          1.648266e+00
# Close        1.658625e+00
# Adj Close    1.541978e+00
# Volume       1.318216e+07
# dtype: float64

# %%
np.std(data6)
# Out:
# Open         2.472666e+00
# High         2.487849e+00
# Low          2.438432e+00
# Close        2.436848e+00
# Adj Close    2.263708e+00
# Volume       1.799363e+07
# dtype: float64

# %%
np.std(data7)
# Out:
# Open         2.590729e+00
# High         2.635766e+00
# Low          2.567893e+00
# Close        2.605630e+00
# Adj Close    2.317203e+00
# Volume       2.002606e+07
# dtype: float64

# %%
np.std(data8)
# Out:
# Open         4.461975e+00
# High         4.461528e+00
# Low          4.453912e+00
# Close        4.468931e+00
# Adj Close    4.146462e+00
# Volume       1.490726e+07
# dtype: float64

# %%
np.std(data9)
# Out:
# Open         1.814787e+00
# High         1.765587e+00
# Low          1.849784e+00
# Close        1.836022e+00
# Adj Close    1.678567e+00
# Volume       1.628659e+07
# dtype: float64

# %%
np.std(data10)
# Out:
# Open         3.694360e+00
# High         3.661581e+00
# Low          3.657960e+00
# Close        3.642580e+00
# Adj Close    3.548028e+00
# Volume       1.478216e+07
# dtype: float64

# %%
np.std(data11)
# Out:
# Open         2.150744e+00
# High         2.157734e+00
# Low          2.128655e+00
# Close        2.166914e+00
# Adj Close    2.178613e+00
# Volume       7.103155e+06
# dtype: float64

# %% [markdown]
# ## **My own example 15**

# %%
X1 = data1['Close']

# %%
X2 = data2['Close']

# %%
X3 = data3['Close']

# %%
X4 = data4['Close']

# %%
X5 = data5['Close']

# %%
X6 = data6['Close']

# %%
X7 = data7['Close']

# %%
X8 = data8['Close']

# %%
X9 = data9['Close']

# %%
X10 = data10['Close']

# %%
X11 = data11['Close']

# %% [markdown]
# ## **My own example 16**

# %%
R1 = X1.pct_change()[1:]

# %%
R2 = X2.pct_change()[1:]

# %%
R3 = X3.pct_change()[1:]

# %%
R4 = X4.pct_change()[1:]

# %%
R5 = X5.pct_change()[1:]

# %%
R6 = X6.pct_change()[1:]

# %%
R7 = X7.pct_change()[1:]

# %%
R8 = X8.pct_change()[1:]

# %%
R9 = X9.pct_change()[1:]

# %%
R10 = X10.pct_change()[1:]

# %%
R11 = X11.pct_change()[1:]

# %% [markdown]
# ## **My own example 17**

# %%
plt.plot(X1.index, X1.values)
plt.ylabel('Price')
plt.legend(['MSFT']);

# %%
plt.plot(X2.index, X2.values)
plt.ylabel('Price')
plt.legend(['MSFT']);

# %%
plt.plot(X3.index, X3.values)
plt.ylabel('Price')
plt.legend(['MSFT']);

# %%
plt.plot(X4.index, X4.values)
plt.ylabel('Price')
plt.legend(['MSFT']);

# %%
plt.plot(X5.index, X5.values)
plt.ylabel('Price')
plt.legend(['MSFT']);

# %%
plt.plot(X6.index, X6.values)
plt.ylabel('Price')
plt.legend(['MSFT']);

# %%
plt.plot(X7.index, X7.values)
plt.ylabel('Price')
plt.legend(['MSFT']);

# %%
plt.plot(X8.index, X8.values)
plt.ylabel('Price')
plt.legend(['MSFT']);

# %%
plt.plot(X9.index, X9.values)
plt.ylabel('Price')
plt.legend(['MSFT']);

# %%
plt.plot(X10.index, X10.values)
plt.ylabel('Price')
plt.legend(['MSFT']);

# %%
plt.plot(X11.index, X11.values)
plt.ylabel('Price')
plt.legend(['MSFT']);

# %% [markdown]
# ## **My own example 18**

# %%
plt.hist(R1, bins=20)
plt.xlabel('Return')
plt.ylabel('Frequency')
plt.legend(['MSFT Returns']);

# %%
plt.hist(R2, bins=20)
plt.xlabel('Return')
plt.ylabel('Frequency')
plt.legend(['MSFT Returns']);

# %%
plt.hist(R3, bins=20)
plt.xlabel('Return')
plt.ylabel('Frequency')
plt.legend(['MSFT Returns']);

# %%
plt.hist(R4, bins=20)
plt.xlabel('Return')
plt.ylabel('Frequency')
plt.legend(['MSFT Returns']);

# %%
plt.hist(R5, bins=20)
plt.xlabel('Return')
plt.ylabel('Frequency')
plt.legend(['MSFT Returns']);

# %%
plt.hist(R6, bins=20)
plt.xlabel('Return')
plt.ylabel('Frequency')
plt.legend(['MSFT Returns']);

# %%
plt.hist(R7, bins=20)
plt.xlabel('Return')
plt.ylabel('Frequency')
plt.legend(['MSFT Returns']);

# %%
plt.hist(R8, bins=20)
plt.xlabel('Return')
plt.ylabel('Frequency')
plt.legend(['MSFT Returns']);

# %%
plt.hist(R9, bins=20)
plt.xlabel('Return')
plt.ylabel('Frequency')
plt.legend(['MSFT Returns']);

# %%
plt.hist(R10, bins=20)
plt.xlabel('Return')
plt.ylabel('Frequency')
plt.legend(['MSFT Returns']);

# %%
plt.hist(R11, bins=20)
plt.xlabel('Return')
plt.ylabel('Frequency')
plt.legend(['MSFT Returns']);

# %% [markdown]
# ## **My own example 19**

# %%
np.std(R1)
# Out:
# 0.012765736344424112

# %%
np.std(R2)
# Out:
# 0.013161522290670963

# %%
np.std(R3)
# Out:
# 0.012096962902866593

# %%
np.std(R4)
# Out:
# 0.017560177850522544

# %%
np.std(R5)
# Out:
# 0.012905458859493677

# %%
np.std(R6)
# Out:
# 0.011288619095592829

# %%
np.std(R7)
# Out:
# 0.01915834704254866

# %%
np.std(R8)
# Out:
# 0.016852171076455816

# %%
np.std(R9)
# Out:
# 0.017382496713934006

# %%
np.std(R10)
# Out:
# 0.011676409767050993

# %%
np.std(R11)
# Out:
# 0.007284758534621343

# %% [markdown]
# ## **My own example 20**

# %%
MAVG = X1.rolling(2).mean()
plt.plot(X1.index, X1.values)
plt.plot(MAVG.index, MAVG.values)
plt.ylabel('Price')
plt.legend(['MSFT', '60-day MAVG']);

# %%
MAVG = X2.rolling(2).mean()
plt.plot(X2.index, X2.values)
plt.plot(MAVG.index, MAVG.values)
plt.ylabel('Price')
plt.legend(['MSFT', '60-day MAVG']);

# %%
MAVG = X3.rolling(2).mean()
plt.plot(X3.index, X3.values)
plt.plot(MAVG.index, MAVG.values)
plt.ylabel('Price')
plt.legend(['MSFT', '60-day MAVG']);

# %%
MAVG = X4.rolling(2).mean()
plt.plot(X4.index, X4.values)
plt.plot(MAVG.index, MAVG.values)
plt.ylabel('Price')
plt.legend(['MSFT', '60-day MAVG']);

# %%
MAVG = X5.rolling(2).mean()
plt.plot(X5.index, X5.values)
plt.plot(MAVG.index, MAVG.values)
plt.ylabel('Price')
plt.legend(['MSFT', '60-day MAVG']);

# %%
MAVG = X6.rolling(2).mean()
plt.plot(X6.index, X6.values)
plt.plot(MAVG.index, MAVG.values)
plt.ylabel('Price')
plt.legend(['MSFT', '60-day MAVG']);

# %%
MAVG = X7.rolling(2).mean()
plt.plot(X7.index, X7.values)
plt.plot(MAVG.index, MAVG.values)
plt.ylabel('Price')
plt.legend(['MSFT', '60-day MAVG']);

# %%
MAVG = X8.rolling(2).mean()
plt.plot(X8.index, X8.values)
plt.plot(MAVG.index, MAVG.values)
plt.ylabel('Price')
plt.legend(['MSFT', '60-day MAVG']);

# %%
MAVG = X9.rolling(2).mean()
plt.plot(X9.index, X9.values)
plt.plot(MAVG.index, MAVG.values)
plt.ylabel('Price')
plt.legend(['MSFT', '60-day MAVG']);

# %%
MAVG = X10.rolling(2).mean()
plt.plot(X10.index, X10.values)
plt.plot(MAVG.index, MAVG.values)
plt.ylabel('Price')
plt.legend(['MSFT', '60-day MAVG']);

# %%
MAVG = X11.rolling(2).mean()
plt.plot(X11.index, X11.values)
plt.plot(MAVG.index, MAVG.values)
plt.ylabel('Price')
plt.legend(['MSFT', '60-day MAVG']);
